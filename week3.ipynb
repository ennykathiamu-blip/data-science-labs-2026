# %%
import pandas as pd

data = {
    "name": ["Aiyana", "Minho", "Zainab", "Simeon"],
    "age": [21, 22, 20],
    "major": ["CS", "stats", "CS"],
    "gpa": [3.85, 3.40, 3.92, 1.23],
    "Gender": ["F", "M", "F"],
}

df= pd.DataFrame(data)
print(df)
# Out:
#      name  age  major   gpa Gender
# 0  Aiyana   21     CS  3.85      F
# 1   Minho   22  stats  3.40      M
# 2  Zainab   20     CS  3.92      F

# %%
print(df.isna().sum())
clean= df.dropna()
df["gpa"]= df["gpa"].fillna(df["gpa"].mean())
df["major"]= df["major"].fillna("unknown")
# Out:
# name      0
# age       0
# major     0
# gpa       0
# Gender    0
# dtype: int64
